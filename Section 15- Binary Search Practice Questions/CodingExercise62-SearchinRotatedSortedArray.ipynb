# %% [markdown]
# Search in Rotated Sorted Array
# Asked in companies:
#
# Microsoft
#
# Amazon
#
# Uber
#
#
#
# Description:
# Given a sorted array that has been rotated, find the index of a given target value. The array was originally sorted in ascending order and then rotated at some pivot.
#
#
#
# Parameters:
#
# nums (List[int]): A list of integers sorted in ascending order but rotated at an unknown pivot.
#
# target (int): The integer value to search for in the array.
#
# Return Values:
#
# int: The index of the target value in the array, or -1 if the target is not in the array.
#
#
#
# Example:
#
# Input: nums = [4, 5, 6, 7, 0, 1, 2], target = 0
# Output: 4
# Explanation: The target value 0 is at index 4 in the rotated array.
#
#
# Input: nums = [4, 5, 6, 7, 0, 1, 2], target = 3
# Output: -1
# Explanation: The target value 3 is not present in the array.
#
#
# Disclaimer: This Udemy coding exercise is still in development, so some advanced complexities might not be fully checked. Please use it primarily for basic code validation.
#
#
#
# LeetCode Link: https://leetcode.com/problems/search-in-rotated-sorted-array/description/
#
#
# All changes saved
# |
# Line 1, Column 1
# Test Cases
# Failed: 5, Passed: 0 of 5 tests
# test_example_1
# test_example_2
# test_target_in_first_half
# test_target_in_second_half
# test_target_not_in_array
# Your code failed this test
# Error details
# None != 4
# Coding Exercise

# %% [markdown]
# Determine which half of the array is sorted.
#
# Based on the sorted half, decide where to continue the binary search for the target.

# %%
def search(nums, target):
    """
    Search for a target value in a rotated sorted array using binary search.
    """
    left, right = 0, len(nums) - 1
    
    while left <= right:
        mid = (left + right) // 2
        
        if nums[mid] == target:
            return mid
        
        # Determine which side is sorted
        if nums[left] <= nums[mid]:
            # Left half is sorted
            if nums[left] <= target < nums[mid]:
                right = mid - 1
            else:
                left = mid + 1
        else:
            # Right half is sorted
            if nums[mid] < target <= nums[right]:
                left = mid + 1
            else:
                right = mid - 1
    
    return -1


print(search([4,5,6,7,0,1,2], 0))  # 4
